# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt

dta = sm.datasets.webuse('lutkepohl2', 'http://www.stata-press.com/data/r12/')
dta.index = dta.qtr
endog = dta.ix['1960-04-01':'1978-10-01', ['dln_inv', 'dln_inc', 'dln_consump']]
# Out:
# d:\app\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# d:\app\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.

# %%
dta.head()
# Out:
#             inv  inc  consump        qtr    ln_inv     dln_inv    ln_inc  \
# qtr
# 1960-01-01  180  451      415 1960-01-01  5.192957 -999.000000  6.111467
# 1960-04-01  179  465      421 1960-04-01  5.187386   -0.005571  6.142037
# 1960-07-01  185  485      434 1960-07-01  5.220356    0.032970  6.184149
# 1960-10-01  192  493      448 1960-10-01  5.257495    0.037139  6.200509
# 1961-01-01  211  509      459 1961-01-01  5.351858    0.094363  6.232448
#
#                dln_inc  ln_consump  dln_consump
# qtr
# 1960-01-01 -999.000000    6.028278  -999.000000
# 1960-04-01    0.030570    6.042633     0.014355
# 1960-07-01    0.042111    6.073044     0.030411
# 1960-10-01    0.016360    6.104793     0.031749
# 1961-01-01    0.031939    6.129050     0.024257

# %%
exog = endog['dln_consump']
mod = sm.tsa.VARMAX(endog[['dln_inv', 'dln_inc']], order=(2,0), trend='nc', exog=exog)
res = mod.fit(maxiter=1000, disp=False)
print(res.summary())
# Out:
#                              Statespace Model Results
# ==================================================================================
# Dep. Variable:     ['dln_inv', 'dln_inc']   No. Observations:                   75
# Model:                            VARX(2)   Log Likelihood                 348.267
# Date:                    Mon, 02 Oct 2017   AIC                           -670.534
# Time:                            10:20:53   BIC                           -640.407
# Sample:                        04-01-1960   HQIC                          -658.504
#                              - 10-01-1978
# Covariance Type:                      opg
# ===================================================================================
# Ljung-Box (Q):                58.82, 42.24   Jarque-Bera (JB):         17.16, 12.80
# Prob(Q):                        0.03, 0.37   Prob(JB):                   0.00, 0.00
# Heteroskedasticity (H):         0.46, 1.03   Skew:                      0.06, -0.63
# Prob(H) (two-sided):            0.06, 0.94   Kurtosis:                   5.34, 4.58
#                             Results for equation dln_inv
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# L1.dln_inv          -0.2710      0.088     -3.072      0.002      -0.444      -0.098
# L1.dln_inc           0.3188      0.621      0.514      0.608      -0.898       1.535
# L2.dln_inv          -0.1155      0.158     -0.733      0.464      -0.424       0.193
# L2.dln_inc           0.4064      0.387      1.050      0.294      -0.353       1.165
# beta.dln_consump     0.5571      0.753      0.740      0.459      -0.918       2.032
#                             Results for equation dln_inc
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# L1.dln_inv           0.0339      0.042      0.803      0.422      -0.049       0.117
# L1.dln_inc           0.0893      0.133      0.673      0.501      -0.171       0.349
# L2.dln_inv           0.0504      0.051      0.986      0.324      -0.050       0.151
# L2.dln_inc           0.2728      0.170      1.608      0.108      -0.060       0.605
# beta.dln_consump     0.4886      0.201      2.437      0.015       0.096       0.882
#                                   Error covariance matrix
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# sqrt.var.dln_inv             0.0441      0.003     14.193      0.000       0.038       0.050
# sqrt.cov.dln_inv.dln_inc     0.0013      0.002      0.547      0.584      -0.003       0.006
# sqrt.var.dln_inc            -0.0128      0.001    -12.398      0.000      -0.015      -0.011
# ============================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# d:\app\Anaconda3\lib\site-packages\statsmodels\base\model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
