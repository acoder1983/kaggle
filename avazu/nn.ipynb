# %%
from os.path import join,exists
from datetime import datetime
import numpy as np
import pandas as pd
import tensorflow as tf
from keras import Model
from keras.layers import Embedding,Activation,Dense,Input,Lambda,Concatenate,Softmax,Dropout,Dot,Add,Multiply
from keras.callbacks import EarlyStopping,Callback
from keras import backend as K
from keras.regularizers import l2
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score
# Out:
# /home/cq/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
not_cate_cols=['id','click','hour']
train_data=pd.read_csv('raw_data/train.csv',dtype={'id':'str'})
test_data=pd.read_csv('raw_data/test.csv',dtype={'id':'str'})
traintst=pd.concat([train_data,test_data]).sample(frac=0.1,random_state=42)
for c in traintst.columns:
    if c not in not_cate_cols:
        traintst[c] = LabelEncoder().fit_transform(traintst[c].astype('str'))
traintst.info(null_counts=True)
# traintst=pd.read_hdf('raw_data/traintst.hdf','avazu')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4500643 entries, 23002356 to 1525489
# Data columns (total 24 columns):
# C1                  4500643 non-null int64
# C14                 4500643 non-null int64
# C15                 4500643 non-null int64
# C16                 4500643 non-null int64
# C17                 4500643 non-null int64
# C18                 4500643 non-null int64
# C19                 4500643 non-null int64
# C20                 4500643 non-null int64
# C21                 4500643 non-null int64
# app_category        4500643 non-null int64
# app_domain          4500643 non-null int64
# app_id              4500643 non-null int64
# banner_pos          4500643 non-null int64
# click               4042456 non-null float64
# device_conn_type    4500643 non-null int64
# device_id           4500643 non-null int64
# device_ip           4500643 non-null int64
# device_model        4500643 non-null int64
# device_type         4500643 non-null int64
# hour                4500643 non-null int64
# id                  4500643 non-null object
# site_category       4500643 non-null int64
# site_domain         4500643 non-null int64
# site_id             4500643 non-null int64
# dtypes: float64(1), int64(22), object(1)
# memory usage: 858.4+ MB

# %%
label_col='click'

time=traintst.hour.astype('str')
time_hour=time.apply(lambda x:int(x[-2:]))

def get_weekday(s):
    return (int(s[:6])-141021)%7+1
time_weekday=time.apply(get_weekday)

traintst['time_hour']=time_hour
traintst['time_weekday']=time_weekday

# %%
tra_data=traintst[traintst.hour<14103000]
val_data=traintst[(traintst.hour>=14103000)&(traintst.hour<14103100)]
tst_data=traintst[traintst.hour>=14103100]
tra_data.shape,val_data.shape,tst_data.shape
# Out:
# ((3620275, 26), (422181, 26), (458187, 26))

# %%
cols_uniq=[(c,len(traintst[c].unique())) for c in set(traintst.columns)-set(not_cate_cols)]
sml_cate_cols=[cu for cu in cols_uniq if cu[1]<100]
print(sml_cate_cols)
med_cate_cols=[cu for cu in cols_uniq if cu[1]>=100 and cu[1]<1000]
print(med_cate_cols)
big_cate_cols=[cu for cu in cols_uniq if cu[1]>=1000 and cu[1]<10000]
print(big_cate_cols)
sup_cate_cols=[cu for cu in cols_uniq if cu[1]>=10000]
print(sup_cate_cols)
# Out:
# [('device_type', 5), ('site_category', 24), ('C15', 8), ('C18', 4), ('C16', 9), ('device_conn_type', 4), ('C1', 7), ('time_weekday', 7), ('C19', 68), ('app_category', 31), ('banner_pos', 7), ('time_hour', 24), ('C21', 61)]
# [('C17', 467), ('C20', 166), ('app_domain', 319)]
# [('app_id', 5216), ('C14', 2673), ('site_domain', 4387), ('device_model', 6402), ('site_id', 3523)]
# [('device_id', 544554), ('device_ip', 1800055)]

# %%
train_root='train'
mi_path=join(train_root,'models_info.hdf')
if exists(mi_path):
    models_info=pd.read_hdf(mi_path)
else:
    models_info=[]

# %%
sel_cols=[c for c in cols_uniq if c[0] != 'device_ip']
cols=[c[0] for c in sel_cols]

x_tra=tra_data[cols]
y_tra=tra_data[label_col]
x_val=val_data[cols]
y_val=val_data[label_col]
x_tst=tst_data[cols]
x_tra.shape,x_val.shape,x_tst.shape
# Out:
# ((3620275, 22), (422181, 22), (458187, 22))

# %%
def auc(y_true, y_pred):
    auc = tf.metrics.auc(y_true, y_pred)[1]
    K.get_session().run(tf.local_variables_initializer())
    return auc

# %%
def lr(sel_cols):
    input=Input((len(sel_cols),))
    attrs=[]
    f=0
    for i in range(len(sel_cols)):
        x=Lambda(lambda x:x[:,i])(input)
#         attrs.append(Embedding(sel_cols[i][1]+1,sel_cols[i][1]+1,embeddings_initializer='identity',trainable=False,dtype='uint8')(x))
        attrs.append(Lambda(lambda x:K.one_hot(K.cast(x,'int32'),sel_cols[i][1]))(x))
        f+=sel_cols[i][1]
    x=Concatenate()(attrs)
    output=Dense(1,activation='sigmoid',kernel_initializer='glorot_uniform')(x)

    model=Model(inputs=input,outputs=output)
    model.name='lr_f%d'%f
    model.compile(optimizer='adam',loss='binary_crossentropy',metrics=[auc])
    model.summary()
    return model

# %%
# K.clear_session()
def fm(sel_cols):
    # embedding dimention
    k=16
    input=Input((len(sel_cols),))

    # set attribute embedding matrix
    attrs_ord1=[]
    attrs_emb=[]
    for i in range(len(sel_cols)):
        x=Lambda(lambda x:x[:,i])(input)
#         attrs_ord1.append(Embedding(sel_cols[i][1]+1,sel_cols[i][1]+1,embeddings_initializer='identity',trainable=False)(x))
        attrs_ord1.append(Lambda(lambda x:K.one_hot(K.cast(x,'int32'),sel_cols[i][1]))(x))
        attrs_emb.append(Embedding(sel_cols[i][1]+1,k,embeddings_initializer='glorot_uniform')(x))

    # calc 2nd order product
    attrs_ord2=[]    
    for i in range(len(sel_cols)):
        for j in range(i+1,len(sel_cols)):
            attrs_ord2.append(Dot(1)([attrs_emb[i],attrs_emb[j]]))

    # lr for 1st order attributes
    x1=Concatenate()(attrs_ord1)
    x1=Dense(1,kernel_initializer='glorot_uniform')(x1)

    # 1st + 2nd 
    attrs_ord2.append(x1)
    x=Add()(attrs_ord2)
    output=Activation('sigmoid')(x)

    model=Model(inputs=input,outputs=output)
    model.name='fm_k%d'%k
    model.compile(optimizer='adam',loss='binary_crossentropy',metrics=[auc])
    model.summary()
    return model

def fm2(sel_cols):
    k=16
    input=Input((len(sel_cols),))
    embs1=[]
    embs2=[]
    for i in range(len(sel_cols)):
        x=Lambda(lambda x:x[:,i])(input)
        attrs_ord1.append(Lambda(lambda x:K.one_hot(K.cast(x,'int32'),sel_cols[i][1]))(x))
        embs2.append(Embedding(sel_cols[i][1]+1,k,embeddings_initializer='glorot_uniform')(x))
    embs3=[]    
    for i in range(len(sel_cols)):
        for j in range(i+1,len(sel_cols)):
            embs3.append(Dot(1)([embs2[i],embs2[j]]))
    
    x=Concatenate()(embs1+embs3)
    output=Dense(1,activation='sigmoid',kernel_initializer='glorot_uniform')(x)

    model=Model(inputs=input,outputs=output)
    model.name='fm2_k%d'%k
    model.compile(optimizer='adam',loss='binary_crossentropy',metrics=[auc])
    model.summary()
    return model

# %%
def deep_fm(sel_cols):
    k=4
    h=256
    reg=1e-5
    input=Input((len(sel_cols),))
    
    # set attribute embedding matrix
    attrs_ord1=[]
    attrs_emb=[]
    for i in range(len(sel_cols)):
        x=Lambda(lambda x:x[:,i])(input)
        attrs_ord1.append(Lambda(lambda x:K.one_hot(K.cast(x,'int32'),sel_cols[i][1]))(x))
        attrs_emb.append(Embedding(sel_cols[i][1]+1,k,embeddings_initializer='glorot_uniform',embeddings_regularizer=l2(reg))(x))

    # calc 2nd order product
    attrs_ord2=[]    
    for i in range(len(sel_cols)):
        for j in range(i+1,len(sel_cols)):
            attrs_ord2.append(Dot(1)([attrs_emb[i],attrs_emb[j]]))
    
    # deep interactions 
    d=Concatenate()(attrs_emb)
    d=Dense(h,activation='relu',kernel_initializer='glorot_uniform',kernel_regularizer=l2(reg))(d)
    d=Dropout(0.75)(d)
    d=Dense(h,activation='relu',kernel_initializer='glorot_uniform',kernel_regularizer=l2(reg))(d)
    d=Dropout(0.5)(d)
    w=Concatenate()(attrs_ord1+attrs_ord2)
    x=Concatenate()([w,d])
    output=Dense(1,activation='sigmoid',kernel_initializer='glorot_uniform',kernel_regularizer=l2(reg))(x)

    model=Model(inputs=input,outputs=output)
    model.name='deep_fm_k%d_h%d'%(k,h)
    model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
    model.summary()
    return model

# %%
# # def attention_fm(sel_cols):
# k=0
# for i in range(len(sel_cols)):
#     k+=sel_cols[i][1]
# k=len(sel_cols)*(len(sel_cols)-1)//2
# input=Input((len(sel_cols),))
# embs1=[]
# embs2=[]
# for i in range(len(sel_cols)):
#     x=Lambda(lambda x:x[:,i])(input)
#     embs1.append(Embedding(sel_cols[i][1]+1,sel_cols[i][1]+1,embeddings_initializer='identity',trainable=False)(x))
#     embs2.append(Embedding(sel_cols[i][1]+1,k,embeddings_initializer='glorot_normal')(x))

# embs3=[]
# atts=[]
# t=256
# w=K.random_normal((k,t))
# h=K.random_normal((1,t))
# b=K.random_normal((1,t))
# for i in range(len(sel_cols)):
#     for j in range(i+1,len(sel_cols)):
#         p=Multiply()([embs2[i],embs2[j]])
#         a=Lambda(lambda p,arguments={'w':w}:K.dot(p,w))(p)
#         a=Activation('relu')(Add()([a,b]))
#         a=Dot(1)([h,a])
#         atts.append(a)
#         embs3.append(p)
# a=Concatenate()(atts)
# a=Softmax()(a)
# emb_pool=Add()(embs3)
# emb_pool=Multiply()([a,emb_pool])

# x=Concatenate()(embs1)
# x=Concatenate()([x,emb_pool])
# output=Dense(1,activation='sigmoid',kernel_initializer='glorot_normal')(x)

# model=Model(inputs=input,outputs=output)
# model.name='attention_fm_k%d'%k
# model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['binary_accuracy'])
# model.summary()
# #     return model

# %%
class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.logs=[]

    def on_epoch_end(self, batch, logs={}):
        self.logs.append(logs)
        
    def train_detail(self):
        log=self.logs[-1]
        log['epochs']=len(self.logs)
        return log
    
class auc_callback(Callback):
    def __init__(self,x_tra,y_tra,x_val,y_val):
        self.x_tra = x_tra
        self.y_tra = y_tra
        self.x_val = x_val
        self.y_val = y_val
        
    def on_train_begin(self, logs={}):
        self.logs=[]

    def on_epoch_end(self, epoch, logs={}):
        y_pred = self.model.predict(self.x_tra)
        self.auc = roc_auc_score(self.y_tra, y_pred)
        y_pred_val = self.model.predict(self.x_val)
        self.auc_val = roc_auc_score(self.y_val, y_pred_val)
        print('\rauc: %.4f - auc_val: %.4f' % (self.auc,self.auc_val),end=100*' '+'\n')
        self.logs.append(logs)
        return
    
    def train_detail(self):
        log=self.logs[-1]
        log['auc']=self.auc
        log['auc_val']=self.auc_val
        return log
    
def run(models,only_compile=False):
    global models_info
    tra_models=[]
    for m in models:
        K.clear_session()
        
        batch_s=128

        if m == 'lr':
            model=lr(sel_cols)
        elif m == 'fm':
            model=fm(sel_cols)
        elif m == 'deep_fm':
            model=deep_fm(sel_cols)
        else:
            model=None
            
        if only_compile:
            continue

        m_info={'model':model.name}
        trainable_count = int(
            np.sum([K.count_params(p) for p in set(model.trainable_weights)]))
        m_info['params_count']=trainable_count

        lh=LossHistory()
        roc=auc_callback(x_tra,y_tra,x_val,y_val)
        model.fit(x_tra,y_tra,validation_data=(x_val,y_val),epochs=100,batch_size=batch_s,
                  callbacks=[EarlyStopping(min_delta=1e-4,patience=1),lh,roc])
        tra_models.append(model)

        results=tst_data[['id']].copy()
        results[label_col]=model.predict(x_tst)
        results[['id',label_col]].to_csv('output/%s_%s.csv'%(datetime.utcnow().strftime('%y%m%d_%H%M%S'),model.name),
                                         index=False,float_format='%.3f')

        m_info.update(lh.train_detail())
        m_info.update(roc.train_detail())
        if str(type(models_info)).find('list')!=-1:
            models_info.append(m_info)
            models_info=pd.DataFrame(models_info)
        else:
            models_info=models_info.append(m_info,ignore_index=True)
        models_info.to_hdf(mi_path,key='models')
        
    return tra_models

# %%
models=run(['fm'])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 22)           0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 467)          0           lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 5)            0           lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 5216)         0           lambda_5[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 24)           0           lambda_7[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 8)            0           lambda_9[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 544554)       0           lambda_11[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 4)            0           lambda_13[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 166)          0           lambda_15[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 9)            0           lambda_17[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 2673)         0           lambda_19[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 4)            0           lambda_21[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 4387)         0           lambda_23[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 7)            0           lambda_25[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 319)          0           lambda_27[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 7)            0           lambda_29[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 68)           0           lambda_31[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 31)           0           lambda_33[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 7)            0           lambda_35[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 6402)         0           lambda_37[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 24)           0           lambda_39[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 61)           0           lambda_41[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 3523)         0           lambda_43[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 16)           7488        lambda_1[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 16)           96          lambda_3[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 16)           83472       lambda_5[0][0]
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 16)           400         lambda_7[0][0]
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 16)           144         lambda_9[0][0]
# __________________________________________________________________________________________________
# embedding_6 (Embedding)         (None, 16)           8712880     lambda_11[0][0]
# __________________________________________________________________________________________________
# embedding_7 (Embedding)         (None, 16)           80          lambda_13[0][0]
# __________________________________________________________________________________________________
# embedding_8 (Embedding)         (None, 16)           2672        lambda_15[0][0]
# __________________________________________________________________________________________________
# embedding_9 (Embedding)         (None, 16)           160         lambda_17[0][0]
# __________________________________________________________________________________________________
# embedding_10 (Embedding)        (None, 16)           42784       lambda_19[0][0]
# __________________________________________________________________________________________________
# embedding_11 (Embedding)        (None, 16)           80          lambda_21[0][0]
# __________________________________________________________________________________________________
# embedding_12 (Embedding)        (None, 16)           70208       lambda_23[0][0]
# __________________________________________________________________________________________________
# embedding_13 (Embedding)        (None, 16)           128         lambda_25[0][0]
# __________________________________________________________________________________________________
# embedding_14 (Embedding)        (None, 16)           5120        lambda_27[0][0]
# __________________________________________________________________________________________________
# embedding_15 (Embedding)        (None, 16)           128         lambda_29[0][0]
# __________________________________________________________________________________________________
# embedding_16 (Embedding)        (None, 16)           1104        lambda_31[0][0]
# __________________________________________________________________________________________________
# embedding_17 (Embedding)        (None, 16)           512         lambda_33[0][0]
# __________________________________________________________________________________________________
# embedding_18 (Embedding)        (None, 16)           128         lambda_35[0][0]
# __________________________________________________________________________________________________
# embedding_19 (Embedding)        (None, 16)           102448      lambda_37[0][0]
# __________________________________________________________________________________________________
# embedding_20 (Embedding)        (None, 16)           400         lambda_39[0][0]
# __________________________________________________________________________________________________
# embedding_21 (Embedding)        (None, 16)           992         lambda_41[0][0]
# __________________________________________________________________________________________________
# embedding_22 (Embedding)        (None, 16)           56384       lambda_43[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 567966)       0           lambda_2[0][0]
#                                                                  lambda_4[0][0]
#                                                                  lambda_6[0][0]
#                                                                  lambda_8[0][0]
#                                                                  lambda_10[0][0]
#                                                                  lambda_12[0][0]
#                                                                  lambda_14[0][0]
#                                                                  lambda_16[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_20[0][0]
#                                                                  lambda_22[0][0]
#                                                                  lambda_24[0][0]
#                                                                  lambda_26[0][0]
#                                                                  lambda_28[0][0]
#                                                                  lambda_30[0][0]
#                                                                  lambda_32[0][0]
#                                                                  lambda_34[0][0]
#                                                                  lambda_36[0][0]
#                                                                  lambda_38[0][0]
#                                                                  lambda_40[0][0]
#                                                                  lambda_42[0][0]
#                                                                  lambda_44[0][0]
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_2[0][0]
# __________________________________________________________________________________________________
# dot_2 (Dot)                     (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_3[0][0]
# __________________________________________________________________________________________________
# dot_3 (Dot)                     (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_4[0][0]
# __________________________________________________________________________________________________
# dot_4 (Dot)                     (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_5[0][0]
# __________________________________________________________________________________________________
# dot_5 (Dot)                     (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_6[0][0]
# __________________________________________________________________________________________________
# dot_6 (Dot)                     (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_7[0][0]
# __________________________________________________________________________________________________
# dot_7 (Dot)                     (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_8[0][0]
# __________________________________________________________________________________________________
# dot_8 (Dot)                     (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_9[0][0]
# __________________________________________________________________________________________________
# dot_9 (Dot)                     (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_10[0][0]
# __________________________________________________________________________________________________
# dot_10 (Dot)                    (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_11[0][0]
# __________________________________________________________________________________________________
# dot_11 (Dot)                    (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_12[0][0]
# __________________________________________________________________________________________________
# dot_12 (Dot)                    (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_13[0][0]
# __________________________________________________________________________________________________
# dot_13 (Dot)                    (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_14[0][0]
# __________________________________________________________________________________________________
# dot_14 (Dot)                    (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_15[0][0]
# __________________________________________________________________________________________________
# dot_15 (Dot)                    (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_16[0][0]
# __________________________________________________________________________________________________
# dot_16 (Dot)                    (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_17[0][0]
# __________________________________________________________________________________________________
# dot_17 (Dot)                    (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_18[0][0]
# __________________________________________________________________________________________________
# dot_18 (Dot)                    (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_19[0][0]
# __________________________________________________________________________________________________
# dot_19 (Dot)                    (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_20[0][0]
# __________________________________________________________________________________________________
# dot_20 (Dot)                    (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_21[0][0]
# __________________________________________________________________________________________________
# dot_21 (Dot)                    (None, 1)            0           embedding_1[0][0]
#                                                                  embedding_22[0][0]
# __________________________________________________________________________________________________
# dot_22 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_3[0][0]
# __________________________________________________________________________________________________
# dot_23 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_4[0][0]
# __________________________________________________________________________________________________
# dot_24 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_5[0][0]
# __________________________________________________________________________________________________
# dot_25 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_6[0][0]
# __________________________________________________________________________________________________
# dot_26 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_7[0][0]
# __________________________________________________________________________________________________
# dot_27 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_8[0][0]
# __________________________________________________________________________________________________
# dot_28 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_9[0][0]
# __________________________________________________________________________________________________
# dot_29 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_10[0][0]
# __________________________________________________________________________________________________
# dot_30 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_11[0][0]
# __________________________________________________________________________________________________
# dot_31 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_12[0][0]
# __________________________________________________________________________________________________
# dot_32 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_13[0][0]
# __________________________________________________________________________________________________
# dot_33 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_14[0][0]
# __________________________________________________________________________________________________
# dot_34 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_15[0][0]
# __________________________________________________________________________________________________
# dot_35 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_16[0][0]
# __________________________________________________________________________________________________
# dot_36 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_17[0][0]
# __________________________________________________________________________________________________
# dot_37 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_18[0][0]
# __________________________________________________________________________________________________
# dot_38 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_19[0][0]
# __________________________________________________________________________________________________
# dot_39 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_20[0][0]
# __________________________________________________________________________________________________
# dot_40 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_21[0][0]
# __________________________________________________________________________________________________
# dot_41 (Dot)                    (None, 1)            0           embedding_2[0][0]
#                                                                  embedding_22[0][0]
# __________________________________________________________________________________________________
# dot_42 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_4[0][0]
# __________________________________________________________________________________________________
# dot_43 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_5[0][0]
# __________________________________________________________________________________________________
# dot_44 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_6[0][0]
# __________________________________________________________________________________________________
# dot_45 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_7[0][0]
# __________________________________________________________________________________________________
# dot_46 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_8[0][0]
# __________________________________________________________________________________________________
# dot_47 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_9[0][0]
# __________________________________________________________________________________________________
# dot_48 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_10[0][0]
# __________________________________________________________________________________________________
# dot_49 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_11[0][0]
# __________________________________________________________________________________________________
# dot_50 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_12[0][0]
# __________________________________________________________________________________________________
# dot_51 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_13[0][0]
# __________________________________________________________________________________________________
# dot_52 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_14[0][0]
# __________________________________________________________________________________________________
# dot_53 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_15[0][0]
# __________________________________________________________________________________________________
# dot_54 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_16[0][0]
# __________________________________________________________________________________________________
# dot_55 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_17[0][0]
# __________________________________________________________________________________________________
# dot_56 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_18[0][0]
# __________________________________________________________________________________________________
# dot_57 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_19[0][0]
# __________________________________________________________________________________________________
# dot_58 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_20[0][0]
# __________________________________________________________________________________________________
# dot_59 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_21[0][0]
# __________________________________________________________________________________________________
# dot_60 (Dot)                    (None, 1)            0           embedding_3[0][0]
#                                                                  embedding_22[0][0]
# __________________________________________________________________________________________________
# dot_61 (Dot)                    (None, 1)            0           embedding_4[0][0]
#                                                                  embedding_5[0][0]
# __________________________________________________________________________________________________
# dot_62 (Dot)                    (None, 1)            0           embedding_4[0][0]
#                                                                  embedding_6[0][0]
# __________________________________________________________________________________________________
# dot_63 (Dot)                    (None, 1)            0           embedding_4[0][0]
#                                                                  embedding_7[0][0]
# __________________________________________________________________________________________________
# dot_64 (Dot)                    (None, 1)            0           embedding_4[0][0]
#                                                                  embedding_8[0][0]
# __________________________________________________________________________________________________
# dot_65 (Dot)                    (None, 1)            0           embedding_4[0][0]
#                                                                  embedding_9[0][0]
# __________________________________________________________________________________________________
# dot_66 (Dot)                    (None, 1)            0           embedding_4[0][0]
#                                                                  embedding_10[0][0]
# __________________________________________________________________________________________________
# dot_67 (Dot)                    (None, 1)            0           embedding_4[0][0]
#                                                                  embedding_11[0][0]
# __________________________________________________________________________________________________
# dot_68 (Dot)                    (None, 1)            0           embedding_4[0][0]
#                                                                  embedding_12[0][0]
# __________________________________________________________________________________________________
# dot_69 (Dot)                    (None, 1)            0           embedding_4[0][0]
#                                                                  embedding_13[0][0]
# __________________________________________________________________________________________________
# dot_70 (Dot)                    (None, 1)            0           embedding_4[0][0]
#                                                                  embedding_14[0][0]
# __________________________________________________________________________________________________
# dot_71 (Dot)                    (None, 1)            0           embedding_4[0][0]
#                                                                  embedding_15[0][0]
# __________________________________________________________________________________________________
# dot_72 (Dot)                    (None, 1)            0           embedding_4[0][0]
#                                                                  embedding_16[0][0]
# __________________________________________________________________________________________________
# dot_73 (Dot)                    (None, 1)            0           embedding_4[0][0]
#                                                                  embedding_17[0][0]
# __________________________________________________________________________________________________
# dot_74 (Dot)                    (None, 1)            0           embedding_4[0][0]
#                                                                  embedding_18[0][0]
# __________________________________________________________________________________________________
# dot_75 (Dot)                    (None, 1)            0           embedding_4[0][0]
#                                                                  embedding_19[0][0]
# __________________________________________________________________________________________________
# dot_76 (Dot)                    (None, 1)            0           embedding_4[0][0]
#                                                                  embedding_20[0][0]
# __________________________________________________________________________________________________
# dot_77 (Dot)                    (None, 1)            0           embedding_4[0][0]
#                                                                  embedding_21[0][0]
# __________________________________________________________________________________________________
# dot_78 (Dot)                    (None, 1)            0           embedding_4[0][0]
#                                                                  embedding_22[0][0]
# __________________________________________________________________________________________________
# dot_79 (Dot)                    (None, 1)            0           embedding_5[0][0]
#                                                                  embedding_6[0][0]
# __________________________________________________________________________________________________
# dot_80 (Dot)                    (None, 1)            0           embedding_5[0][0]
#                                                                  embedding_7[0][0]
# __________________________________________________________________________________________________
# dot_81 (Dot)                    (None, 1)            0           embedding_5[0][0]
#                                                                  embedding_8[0][0]
# __________________________________________________________________________________________________
# dot_82 (Dot)                    (None, 1)            0           embedding_5[0][0]
#                                                                  embedding_9[0][0]
# __________________________________________________________________________________________________
# dot_83 (Dot)                    (None, 1)            0           embedding_5[0][0]
#                                                                  embedding_10[0][0]
# __________________________________________________________________________________________________
# dot_84 (Dot)                    (None, 1)            0           embedding_5[0][0]
#                                                                  embedding_11[0][0]
# __________________________________________________________________________________________________
# dot_85 (Dot)                    (None, 1)            0           embedding_5[0][0]
#                                                                  embedding_12[0][0]
# __________________________________________________________________________________________________
# dot_86 (Dot)                    (None, 1)            0           embedding_5[0][0]
#                                                                  embedding_13[0][0]
# __________________________________________________________________________________________________
# dot_87 (Dot)                    (None, 1)            0           embedding_5[0][0]
#                                                                  embedding_14[0][0]
# __________________________________________________________________________________________________
# dot_88 (Dot)                    (None, 1)            0           embedding_5[0][0]
#                                                                  embedding_15[0][0]
# __________________________________________________________________________________________________
# dot_89 (Dot)                    (None, 1)            0           embedding_5[0][0]
#                                                                  embedding_16[0][0]
# __________________________________________________________________________________________________
# dot_90 (Dot)                    (None, 1)            0           embedding_5[0][0]
#                                                                  embedding_17[0][0]
# __________________________________________________________________________________________________
# dot_91 (Dot)                    (None, 1)            0           embedding_5[0][0]
#                                                                  embedding_18[0][0]
# __________________________________________________________________________________________________
# dot_92 (Dot)                    (None, 1)            0           embedding_5[0][0]
#                                                                  embedding_19[0][0]
# __________________________________________________________________________________________________
# dot_93 (Dot)                    (None, 1)            0           embedding_5[0][0]
#                                                                  embedding_20[0][0]
# __________________________________________________________________________________________________
# dot_94 (Dot)                    (None, 1)            0           embedding_5[0][0]
#                                                                  embedding_21[0][0]
# __________________________________________________________________________________________________
# dot_95 (Dot)                    (None, 1)            0           embedding_5[0][0]
#                                                                  embedding_22[0][0]
# __________________________________________________________________________________________________
# dot_96 (Dot)                    (None, 1)            0           embedding_6[0][0]
#                                                                  embedding_7[0][0]
# __________________________________________________________________________________________________
# dot_97 (Dot)                    (None, 1)            0           embedding_6[0][0]
#                                                                  embedding_8[0][0]
# __________________________________________________________________________________________________
# dot_98 (Dot)                    (None, 1)            0           embedding_6[0][0]
#                                                                  embedding_9[0][0]
# __________________________________________________________________________________________________
# dot_99 (Dot)                    (None, 1)            0           embedding_6[0][0]
#                                                                  embedding_10[0][0]
# __________________________________________________________________________________________________
# dot_100 (Dot)                   (None, 1)            0           embedding_6[0][0]
#                                                                  embedding_11[0][0]
# __________________________________________________________________________________________________
# dot_101 (Dot)                   (None, 1)            0           embedding_6[0][0]
#                                                                  embedding_12[0][0]
# __________________________________________________________________________________________________
# dot_102 (Dot)                   (None, 1)            0           embedding_6[0][0]
#                                                                  embedding_13[0][0]
# __________________________________________________________________________________________________
# dot_103 (Dot)                   (None, 1)            0           embedding_6[0][0]
#                                                                  embedding_14[0][0]
# __________________________________________________________________________________________________
# dot_104 (Dot)                   (None, 1)            0           embedding_6[0][0]
#                                                                  embedding_15[0][0]
# __________________________________________________________________________________________________
# dot_105 (Dot)                   (None, 1)            0           embedding_6[0][0]
#                                                                  embedding_16[0][0]
# __________________________________________________________________________________________________
# dot_106 (Dot)                   (None, 1)            0           embedding_6[0][0]
#                                                                  embedding_17[0][0]
# __________________________________________________________________________________________________
# dot_107 (Dot)                   (None, 1)            0           embedding_6[0][0]
#                                                                  embedding_18[0][0]
# __________________________________________________________________________________________________
# dot_108 (Dot)                   (None, 1)            0           embedding_6[0][0]
#                                                                  embedding_19[0][0]
# __________________________________________________________________________________________________
# ...
#                                                                  dot_82[0][0]
#                                                                  dot_83[0][0]
#                                                                  dot_84[0][0]
#                                                                  dot_85[0][0]
#                                                                  dot_86[0][0]
#                                                                  dot_87[0][0]
#                                                                  dot_88[0][0]
#                                                                  dot_89[0][0]
#                                                                  dot_90[0][0]
#                                                                  dot_91[0][0]
#                                                                  dot_92[0][0]
#                                                                  dot_93[0][0]
#                                                                  dot_94[0][0]
#                                                                  dot_95[0][0]
#                                                                  dot_96[0][0]
#                                                                  dot_97[0][0]
#                                                                  dot_98[0][0]
#                                                                  dot_99[0][0]
#                                                                  dot_100[0][0]
#                                                                  dot_101[0][0]
#                                                                  dot_102[0][0]
#                                                                  dot_103[0][0]
#                                                                  dot_104[0][0]
#                                                                  dot_105[0][0]
#                                                                  dot_106[0][0]
#                                                                  dot_107[0][0]
#                                                                  dot_108[0][0]
#                                                                  dot_109[0][0]
#                                                                  dot_110[0][0]
#                                                                  dot_111[0][0]
#                                                                  dot_112[0][0]
#                                                                  dot_113[0][0]
#                                                                  dot_114[0][0]
#                                                                  dot_115[0][0]
#                                                                  dot_116[0][0]
#                                                                  dot_117[0][0]
#                                                                  dot_118[0][0]
#                                                                  dot_119[0][0]
#                                                                  dot_120[0][0]
#                                                                  dot_121[0][0]
#                                                                  dot_122[0][0]
#                                                                  dot_123[0][0]
#                                                                  dot_124[0][0]
#                                                                  dot_125[0][0]
#                                                                  dot_126[0][0]
#                                                                  dot_127[0][0]
#                                                                  dot_128[0][0]
#                                                                  dot_129[0][0]
#                                                                  dot_130[0][0]
#                                                                  dot_131[0][0]
#                                                                  dot_132[0][0]
#                                                                  dot_133[0][0]
#                                                                  dot_134[0][0]
#                                                                  dot_135[0][0]
#                                                                  dot_136[0][0]
#                                                                  dot_137[0][0]
#                                                                  dot_138[0][0]
#                                                                  dot_139[0][0]
#                                                                  dot_140[0][0]
#                                                                  dot_141[0][0]
#                                                                  dot_142[0][0]
#                                                                  dot_143[0][0]
#                                                                  dot_144[0][0]
#                                                                  dot_145[0][0]
#                                                                  dot_146[0][0]
#                                                                  dot_147[0][0]
#                                                                  dot_148[0][0]
#                                                                  dot_149[0][0]
#                                                                  dot_150[0][0]
#                                                                  dot_151[0][0]
#                                                                  dot_152[0][0]
#                                                                  dot_153[0][0]
#                                                                  dot_154[0][0]
#                                                                  dot_155[0][0]
#                                                                  dot_156[0][0]
#                                                                  dot_157[0][0]
#                                                                  dot_158[0][0]
#                                                                  dot_159[0][0]
#                                                                  dot_160[0][0]
#                                                                  dot_161[0][0]
#                                                                  dot_162[0][0]
#                                                                  dot_163[0][0]
#                                                                  dot_164[0][0]
#                                                                  dot_165[0][0]
#                                                                  dot_166[0][0]
#                                                                  dot_167[0][0]
#                                                                  dot_168[0][0]
#                                                                  dot_169[0][0]
#                                                                  dot_170[0][0]
#                                                                  dot_171[0][0]
#                                                                  dot_172[0][0]
#                                                                  dot_173[0][0]
#                                                                  dot_174[0][0]
#                                                                  dot_175[0][0]
#                                                                  dot_176[0][0]
#                                                                  dot_177[0][0]
#                                                                  dot_178[0][0]
#                                                                  dot_179[0][0]
#                                                                  dot_180[0][0]
#                                                                  dot_181[0][0]
#                                                                  dot_182[0][0]
#                                                                  dot_183[0][0]
#                                                                  dot_184[0][0]
#                                                                  dot_185[0][0]
#                                                                  dot_186[0][0]
#                                                                  dot_187[0][0]
#                                                                  dot_188[0][0]
#                                                                  dot_189[0][0]
#                                                                  dot_190[0][0]
#                                                                  dot_191[0][0]
#                                                                  dot_192[0][0]
#                                                                  dot_193[0][0]
#                                                                  dot_194[0][0]
#                                                                  dot_195[0][0]
#                                                                  dot_196[0][0]
#                                                                  dot_197[0][0]
#                                                                  dot_198[0][0]
#                                                                  dot_199[0][0]
#                                                                  dot_200[0][0]
#                                                                  dot_201[0][0]
#                                                                  dot_202[0][0]
#                                                                  dot_203[0][0]
#                                                                  dot_204[0][0]
#                                                                  dot_205[0][0]
#                                                                  dot_206[0][0]
#                                                                  dot_207[0][0]
#                                                                  dot_208[0][0]
#                                                                  dot_209[0][0]
#                                                                  dot_210[0][0]
#                                                                  dot_211[0][0]
#                                                                  dot_212[0][0]
#                                                                  dot_213[0][0]
#                                                                  dot_214[0][0]
#                                                                  dot_215[0][0]
#                                                                  dot_216[0][0]
#                                                                  dot_217[0][0]
#                                                                  dot_218[0][0]
#                                                                  dot_219[0][0]
#                                                                  dot_220[0][0]
#                                                                  dot_221[0][0]
#                                                                  dot_222[0][0]
#                                                                  dot_223[0][0]
#                                                                  dot_224[0][0]
#                                                                  dot_225[0][0]
#                                                                  dot_226[0][0]
#                                                                  dot_227[0][0]
#                                                                  dot_228[0][0]
#                                                                  dot_229[0][0]
#                                                                  dot_230[0][0]
#                                                                  dot_231[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1)            0           add_1[0][0]
# ==================================================================================================
# Total params: 9,655,775
# Trainable params: 9,655,775
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 3620275 samples, validate on 422181 samples
# Epoch 1/100
# 3620275/3620275 [==============================] - 2503s 691us/step - loss: 0.3987 - auc: 0.7331 - val_loss: 0.4065 - val_auc: 0.7453
# auc: 0.7713 - auc_val: 0.7356
# Epoch 2/100
# 3620275/3620275 [==============================] - 2503s 691us/step - loss: 0.3860 - auc: 0.7520 - val_loss: 0.4102 - val_auc: 0.7556
# auc: 0.7897 - auc_val: 0.7235

# %%
models_info[['model','params_count','epochs','loss','val_loss']]
# Out:
#               model  params_count  epochs      loss  val_loss
# 0         lr_f33342         33364       3  0.395412  0.400594
# 1             fm_16        567172       3  0.387692  0.404866
# 2  deep_fm_k16_h256        740591      12  0.494015  0.536752
# 3  deep_fm_k16_h256        740591       2  0.394316  0.553624
# 4   deep_fm_k4_h256        205163       3  0.398473  0.403810
# 5   deep_fm_k4_h256       2928982       2  0.398929  0.406616
# 6            fm_k16       9655775       2  0.385956  0.410166
