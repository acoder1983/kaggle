# %%
from os.path import join,exists
from datetime import datetime
import numpy as np
import pandas as pd
import tensorflow as tf
from keras import Model
from keras.layers import Embedding,Activation,Dense,Input,Lambda,Concatenate,Softmax,Dropout,Dot,Add,Multiply,Reshape
from keras.callbacks import EarlyStopping,Callback
from keras.metrics import binary_crossentropy
from keras import backend as K
from sklearn.preprocessing import LabelEncoder,StandardScaler
from tqdm import tnrange
# Out:
# /home/cq/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# %%time
big_data=pd.read_hdf('raw_data/big_int_proc.hdf',key='big')
label=pd.read_hdf('raw_data/label.hdf',key='label').values.ravel()

int_fea_num=13
cat_fea_num=26
    
tst_len=6042135
val_len=6000000
x_tra,y_tra,x_val,y_val,x_tst=big_data[:big_data.shape[0]-val_len-tst_len],label[:big_data.shape[0]-val_len-tst_len],big_data[big_data.shape[0]-val_len-tst_len:big_data.shape[0]-tst_len],label[-val_len:],big_data[big_data.shape[0]-tst_len:]
print(x_tra.shape,y_tra.shape,x_val.shape,y_val.shape,x_tst.shape)
# Out:
# (39840617, 39) (39840617,) (6000000, 39) (6000000,) (6042135, 39)
# CPU times: user 40 ms, sys: 7.99 s, total: 8.03 s
# Wall time: 8.03 s

# %%
# %%time
emb_dim={}
for c in range(int_fea_num,int_fea_num+cat_fea_num):
    emb_dim[c]=big_data[c].max()+1
sorted_emb_dim=sorted([(c,emb_dim[c]) for c in emb_dim],key=lambda x:x[1],reverse=True)
print(sorted_emb_dim)
drop_cols=[e[0] for e in sorted_emb_dim if e[1]>1000000]
# Out:
# [(15, 11299105), (24, 9292738), (33, 7822987), (28, 6047969), (16, 2416541), (36, 303075), (38, 148165), (22, 95979), (27, 15210), (19, 12597), (23, 5724), (30, 5721), (25, 3207), (31, 2178), (13, 1460), (20, 633), (14, 585), (17, 305), (37, 105), (26, 27), (18, 24), (34, 18), (35, 15), (29, 10), (32, 4), (21, 3)]
# CPU times: user 40.6 s, sys: 2.66 s, total: 43.3 s
# Wall time: 43.3 s

# %%
train_root='train'
mi_path=join(train_root,'models_info.hdf')
if exists(mi_path):
    models_info=pd.read_hdf(mi_path)
else:
    models_info=[]

# %%
def dnn(input_dim):
    input=Input((input_dim,))
    attrs=[]
    f=0
    k=8
    h=64
    for i in range(input_dim):
        x=Lambda(lambda x:x[:,i])(input)
        if i in drop_cols:
            continue
        if i < int_fea_num:
            attrs.append(Reshape((1,))(x))
        else:
            attrs.append(Embedding(emb_dim[i]+1,k)(x))
        f+=1
    x=Concatenate()(attrs)
    x=Dense(h,activation='relu')(x)
    x=Dense(h//4,activation='relu')(x)
    output=Dense(1,activation='sigmoid')(x)

    model=Model(inputs=input,outputs=output)
    model.name='dnn_f%d_k%d_h%d_h%d'%(f,k,h,h//4)
    model.compile(optimizer='adam',loss='binary_crossentropy',metrics=[binary_crossentropy])
    model.summary()
    return model

class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.logs=[]

    def on_epoch_end(self, batch, logs={}):
        self.logs.append(logs)
        
    def train_detail(self):
        log=self.logs[-1]
        log['epochs']=len(self.logs)
        return log

    
def run(models,only_compile=False):
    global models_info
    tra_models=[]
    for m in models:
        K.clear_session()
        
        batch_s=256

        if m == 'dnn':
            model=dnn(big_data.shape[1])
        else:
            model=None
            
        if only_compile:
            continue

        m_info={'model':model.name}
        trainable_count = int(
            np.sum([K.count_params(p) for p in set(model.trainable_weights)]))
        m_info['params_count']=trainable_count

        lh=LossHistory()
#         model.fit(x_tra,y_tra,validation_data=(x_val,y_val),epochs=100,batch_size=batch_s,
#                   callbacks=[EarlyStopping(min_delta=1e-3,patience=1),lh])
        model.fit(x_tra,y_tra,epochs=2,batch_size=batch_s,
                  callbacks=[lh])
        tra_models.append(model)

        
        m_info.update(lh.train_detail())
        if str(type(models_info)).find('list')!=-1:
            models_info.append(m_info)
            models_info=pd.DataFrame(models_info)
        else:
            models_info=models_info.append(m_info,ignore_index=True)
        models_info.to_hdf(mi_path,key='models')
        
    return tra_models

# %%
x_tra,y_tra=big_data[:big_data.shape[0]-tst_len],label[:big_data.shape[0]-tst_len]
x_tra.shape,y_tra.shape
# Out:
# ((45840617, 39), (45840617,))

# %%
models=run(['dnn'])
models_info[['model','params_count','epochs','loss','val_loss']]
# Out:
# WARNING:tensorflow:From /home/cq/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 39)           0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None,)              0           input_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1)            0           lambda_1[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1)            0           lambda_2[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 1)            0           lambda_3[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1)            0           lambda_4[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 1)            0           lambda_5[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1)            0           lambda_6[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1)            0           lambda_7[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1)            0           lambda_8[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 1)            0           lambda_9[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 1)            0           lambda_10[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 1)            0           lambda_11[0][0]
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 1)            0           lambda_12[0][0]
# __________________________________________________________________________________________________
# reshape_13 (Reshape)            (None, 1)            0           lambda_13[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 8)            11688       lambda_14[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 8)            4688        lambda_15[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 8)            2448        lambda_18[0][0]
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 8)            200         lambda_19[0][0]
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 8)            100784      lambda_20[0][0]
# __________________________________________________________________________________________________
# embedding_6 (Embedding)         (None, 8)            5072        lambda_21[0][0]
# __________________________________________________________________________________________________
# embedding_7 (Embedding)         (None, 8)            32          lambda_22[0][0]
# __________________________________________________________________________________________________
# embedding_8 (Embedding)         (None, 8)            767840      lambda_23[0][0]
# __________________________________________________________________________________________________
# embedding_9 (Embedding)         (None, 8)            45800       lambda_24[0][0]
# __________________________________________________________________________________________________
# embedding_10 (Embedding)        (None, 8)            25664       lambda_26[0][0]
# __________________________________________________________________________________________________
# embedding_11 (Embedding)        (None, 8)            224         lambda_27[0][0]
# __________________________________________________________________________________________________
# embedding_12 (Embedding)        (None, 8)            121688      lambda_28[0][0]
# __________________________________________________________________________________________________
# embedding_13 (Embedding)        (None, 8)            88          lambda_30[0][0]
# __________________________________________________________________________________________________
# embedding_14 (Embedding)        (None, 8)            45776       lambda_31[0][0]
# __________________________________________________________________________________________________
# embedding_15 (Embedding)        (None, 8)            17432       lambda_32[0][0]
# __________________________________________________________________________________________________
# embedding_16 (Embedding)        (None, 8)            40          lambda_33[0][0]
# __________________________________________________________________________________________________
# embedding_17 (Embedding)        (None, 8)            152         lambda_35[0][0]
# __________________________________________________________________________________________________
# embedding_18 (Embedding)        (None, 8)            128         lambda_36[0][0]
# __________________________________________________________________________________________________
# embedding_19 (Embedding)        (None, 8)            2424608     lambda_37[0][0]
# __________________________________________________________________________________________________
# embedding_20 (Embedding)        (None, 8)            848         lambda_38[0][0]
# __________________________________________________________________________________________________
# embedding_21 (Embedding)        (None, 8)            1185328     lambda_39[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 181)          0           reshape_1[0][0]
#                                                                  reshape_2[0][0]
#                                                                  reshape_3[0][0]
#                                                                  reshape_4[0][0]
#                                                                  reshape_5[0][0]
#                                                                  reshape_6[0][0]
#                                                                  reshape_7[0][0]
#                                                                  reshape_8[0][0]
#                                                                  reshape_9[0][0]
#                                                                  reshape_10[0][0]
#                                                                  reshape_11[0][0]
#                                                                  reshape_12[0][0]
#                                                                  reshape_13[0][0]
#                                                                  embedding_1[0][0]
#                                                                  embedding_2[0][0]
#                                                                  embedding_3[0][0]
#                                                                  embedding_4[0][0]
#                                                                  embedding_5[0][0]
#                                                                  embedding_6[0][0]
#                                                                  embedding_7[0][0]
#                                                                  embedding_8[0][0]
#                                                                  embedding_9[0][0]
#                                                                  embedding_10[0][0]
#                                                                  embedding_11[0][0]
#                                                                  embedding_12[0][0]
#                                                                  embedding_13[0][0]
#                                                                  embedding_14[0][0]
#                                                                  embedding_15[0][0]
#                                                                  embedding_16[0][0]
#                                                                  embedding_17[0][0]
#                                                                  embedding_18[0][0]
#                                                                  embedding_19[0][0]
#                                                                  embedding_20[0][0]
#                                                                  embedding_21[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           11648       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           1040        dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            17          dense_2[0][0]
# ==================================================================================================
# Total params: 4,773,233
# Trainable params: 4,773,233
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:From /home/cq/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/2
# 45840617/45840617 [==============================] - 5641s 123us/step - loss: 0.4561 - binary_crossentropy: 0.4561
# Epoch 2/2
# 45840617/45840617 [==============================] - 5615s 122us/step - loss: 0.4497 - binary_crossentropy: 0.4497
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-d6d040df7fc7> in <module>()
#       1 models=run(['dnn'])
# ----> 2 models_info[['model','params_count','epochs','loss','val_loss']]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1267                 if mask.any():
#    1268                     raise KeyError('{mask} not in index'
# -> 1269                                    .format(mask=objarr[mask]))
#    1270
#    1271                 return _values_from_object(indexer)
#
# KeyError: "['val_loss'] not in index"

# %%
result=pd.read_csv('raw_data/random_submission.csv',dtype={'Id':'str'})
result.Predicted=models[0].predict(x_tst)
result[['Id','Predicted']].to_csv('output/%s.csv'%models[0].name,index=False)
